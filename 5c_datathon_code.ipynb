# %% [markdown]
# How to download Kaggle Data https://www.kaggle.com/discussions/general/74235

# %%
# Import neseccary modules.
import pandas as pd
import numpy as np

# %% [markdown]
# Load the dataset

# %%
train_data = pd.read_csv("datathon_train.csv")

# %% [markdown]
# Begin preliminary analysis of the data. Exploratory phase

# %%
# Drop the Id column
train_data.drop("Id", axis=1, inplace=True)

# %%
# Get summary statistics
train_data.describe()
# Out:
#                MONTH   DAY_OF_MONTH    DAY_OF_WEEK       DISTANCE  \
# count  697224.000000  697224.000000  697224.000000  697224.000000
# mean        6.620198      15.723732       3.931059     852.680886
# std         3.397212       8.756372       1.996984     611.715805
# min         1.000000       1.000000       1.000000      66.000000
# 25%         4.000000       8.000000       2.000000     402.000000
# 50%         7.000000      16.000000       4.000000     687.000000
# 75%        10.000000      23.000000       6.000000    1087.000000
# max        12.000000      31.000000       7.000000    5095.000000
#
#        SEGMENT_NUMBER  CONCURRENT_FLIGHTS  MANUFACTURE_YEAR  NUMBER_OF_SEATS  \
# count   697224.000000       697224.000000     697224.000000    697224.000000
# mean         3.064137           28.073635       2007.433931       134.799211
# std          1.759975           21.329959          7.046577        47.035304
# min          1.000000            1.000000       1987.000000        44.000000
# 25%          2.000000           11.000000       2002.000000        90.000000
# 50%          3.000000           23.000000       2007.000000       143.000000
# 75%          4.000000           39.000000       2014.000000       173.000000
# max         15.000000          109.000000       2019.000000       337.000000
#
#        AIRPORT_FLIGHTS_MONTH  AIRLINE_FLIGHTS_MONTH  ...  \
# count          697224.000000           697224.00000  ...
# mean            12398.966083            63379.64382  ...
# std              8315.616727            33670.96123  ...
# min              1100.000000              835.00000  ...
# 25%              5445.000000            25367.00000  ...
# 50%             11398.000000            68293.00000  ...
# 75%             17499.000000            84667.00000  ...
# max             33340.000000           116615.00000  ...
#
#        FLT_ATTENDANTS_PER_PASS  GROUND_SERV_PER_PASS      PLANE_AGE  \
# count            697224.000000         697224.000000  697224.000000
# mean                  0.000099              0.000135      11.566069
# std                   0.000085              0.000047       7.046577
# min                   0.000000              0.000007       0.000000
# 25%                   0.000034              0.000099       5.000000
# 50%                   0.000062              0.000125      12.000000
# 75%                   0.000144              0.000177      17.000000
# max                   0.000348              0.000229      32.000000
#
#                 PRCP           SNOW           SNWD           TMAX  \
# count  697224.000000  697224.000000  697224.000000  697224.000000
# mean        0.104860       0.032057       0.090429      71.472508
# std         0.342738       0.318871       0.724490      18.356162
# min         0.000000       0.000000       0.000000     -10.000000
# 25%         0.000000       0.000000       0.000000      59.000000
# 50%         0.000000       0.000000       0.000000      74.000000
# 75%         0.020000       0.000000       0.000000      86.000000
# max        11.630000      17.200000      25.200000     115.000000
#
#                 AWND  DEP_DELAY_NEW     IS_DELAYED
# count  697224.000000  697224.000000  697224.000000
# mean        8.369713      15.409382       0.399027
# std         3.609616      47.385170       0.489699
# min         0.000000       0.000000       0.000000
# 25%         5.820000       0.000000       0.000000
# 50%         7.830000       0.000000       0.000000
# 75%        10.510000      10.000000       1.000000
# max        33.780000    1742.000000       1.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# Do we have an imbalanced dataset? Yes...yes we do.

# %%
# Do we have an imbalanced dataset? Let's find the distribution of the target variable
# Notice how there are many more flights (rows) that aren't delayed than flights that are
pd.value_counts(train_data["IS_DELAYED"])
# Out:
# /var/folders/p6/0vclxwpx5bn0v72kzlpwhszr0000gn/T/ipykernel_9274/640870604.py:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(train_data["IS_DELAYED"])
# IS_DELAYED
# 0    419013
# 1    278211
# Name: count, dtype: int64

# %% [markdown]
# Let's decide what columns/features to use in our prediction.

# %%
train_data.columns
# Out:
# Index(['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'DEPARTING_AIRPORT',
#        'ORIGIN_CITY_NAME', 'DEST', 'DEST_CITY_NAME', 'DEP_TIME_BLK',
#        'DISTANCE', 'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS', 'MANUFACTURE_YEAR',
#        'NUMBER_OF_SEATS', 'CARRIER_NAME', 'AIRPORT_FLIGHTS_MONTH',
#        'AIRLINE_FLIGHTS_MONTH', 'AIRLINE_AIRPORT_FLIGHTS_MONTH',
#        'AVG_MONTHLY_PASS_AIRPORT', 'AVG_MONTHLY_PASS_AIRLINE',
#        'CARGO_HANDLING', 'FLT_ATTENDANTS_PER_PASS', 'GROUND_SERV_PER_PASS',
#        'PLANE_AGE', 'PREVIOUS_AIRPORT', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'AWND',
#        'DEP_DELAY_NEW', 'IS_DELAYED'],
#       dtype='object')

# %% [markdown]
# 1. Are any the features basically the "same" as another feature? Well, the airports and cities say the same thing, DEP_DEL_NEW should be removed, and manufacture year is the same variable as the age of the plane.

# %%
# Let's drop the redundant features to reduce our training time in the future
train_data.drop(['ORIGIN_CITY_NAME', 'DEST_CITY_NAME', 'MANUFACTURE_YEAR', 'DEP_DELAY_NEW','PREVIOUS_AIRPORT'], axis=1, inplace=True)

# %% [markdown]
# Next, we have to turn the categorical variales into numbers so we can use them to train our model! We'll use sklearn's `LabelEncoder()` for this.

# %% [markdown]
# Here's how a label encoder works:
#
# `fit`
# If we have a list of discrete variables, like ["a", "b", "b", "c"], the label encoder will locate each unique item in the list ("a", "b", "c") and assign an integer to that object, for instance,
#
# "a" -> 0
#
# "b" -> 1
#
# "c" -> 2
#
# `transform`
# Now, when we encounter a list like ["b", "b", "c", "a"], the LabelENcoder will perform the translation between string and number, and output [1, 1, 2, 0]. Essentially, replacing the string with the corresponding number.
#
# Label encoders, however, do not handle unseen values. So, if we try to translate "d", the LabelEncoder will through a bad error. If out training set contains only "a", "b", and "c", and our testing set contains a new string "d", we'll run into a problem. To account for this, we'll add an "UNSEEN" to the unique items in the list, so when we encounter an unknown value in the testing set, we'll replace it with "UNSEEN" and continue encoding.

# %%
# For each of the string, categorical variables, we must encode these values as numbers.
from sklearn.preprocessing import LabelEncoder

dest_le = LabelEncoder().fit(train_data["DEST"].tolist() + ["UNSEEN"])
train_data["DEST"] = dest_le.transform(train_data["DEST"])

carrier_name_le = LabelEncoder().fit(train_data["CARRIER_NAME"].tolist()+ ["UNSEEN"])
train_data["CARRIER_NAME"] = carrier_name_le.transform(train_data["CARRIER_NAME"])

dep_time_blk_le = LabelEncoder().fit(train_data["DEP_TIME_BLK"].tolist()+ ["UNSEEN"])
train_data["DEP_TIME_BLK"] = dep_time_blk_le.transform(train_data["DEP_TIME_BLK"])

departing_airport_le = LabelEncoder().fit(train_data["DEPARTING_AIRPORT"].tolist()+ ["UNSEEN"])
train_data["DEPARTING_AIRPORT"] = departing_airport_le.transform(train_data["DEPARTING_AIRPORT"])

# %% [markdown]
# 2. For this starter code, I'll select 5 random variables to use as my features. You should do your own selection, and think about what features would be useful!

# %%
train_data = train_data[['DEST',
       'DEP_TIME_BLK', 'DISTANCE', 'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS',
       'NUMBER_OF_SEATS', 'CARRIER_NAME', 'AIRPORT_FLIGHTS_MONTH',
       'AIRLINE_FLIGHTS_MONTH', 'AIRLINE_AIRPORT_FLIGHTS_MONTH',
       'AVG_MONTHLY_PASS_AIRPORT', 'AVG_MONTHLY_PASS_AIRLINE',
       'CARGO_HANDLING','PLANE_AGE', 'PRCP', 'SNOW', 'SNWD', 'AWND','IS_DELAYED']]

# %%
train_data = train_data[['AWND','AIRLINE_FLIGHTS_MONTH','DISTANCE','AVG_MONTHLY_PASS_AIRLINE','SNOW','PRCP','SEGMENT_NUMBER','CARGO HANDLING','IS_DELAYED']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/markwang/Desktop/5C Datathon/5c_datathon_starter_code.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/Users/markwang/Desktop/5C%20Datathon/5c_datathon_starter_code.ipynb#Y163sZmlsZQ%3D%3D?line=0'>1</a> train_data = train_data[['AWND','AIRLINE_FLIGHTS_MONTH','DISTANCE','AVG_MONTHLY_PASS_AIRLINE','SNOW','PRCP','SEGMENT_NUMBER','CARGO HANDLING','IS_DELAYED']]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6178, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['CARGO HANDLING'] not in index"

# %%
train_data = train_data[['AWND','DISTANCE','AIRLINE_AIRPORT_FLIGHTS_MONTH','SNOW','NUMBER_OF_SEATS','PRCP','SEGMENT_NUMBER', 'AIRLINE_FLIGHTS_MONTH', 'AVG_MONTHLY_PASS_AIRLINE','CARGO_HANDLING', 'IS_DELAYED']]

# %%
train_data.corr()
# Out:
#                                   MONTH  DAY_OF_MONTH  DAY_OF_WEEK  \
# MONTH                          1.000000      0.007900     0.004115
# DAY_OF_MONTH                   0.007900      1.000000     0.007654
# DAY_OF_WEEK                    0.004115      0.007654     1.000000
# DEPARTING_AIRPORT             -0.003732      0.002837     0.001732
# DEST                          -0.006372     -0.001285     0.002943
# DEP_TIME_BLK                   0.000513     -0.001562     0.008441
# DISTANCE                      -0.003786      0.001973     0.014112
# SEGMENT_NUMBER                 0.020130     -0.000607    -0.026466
# CONCURRENT_FLIGHTS             0.026436      0.000660    -0.027232
# NUMBER_OF_SEATS                0.002932      0.000729     0.009340
# CARRIER_NAME                  -0.000473      0.000292    -0.001468
# AIRPORT_FLIGHTS_MONTH          0.052192      0.002913    -0.002124
# AIRLINE_FLIGHTS_MONTH          0.052835      0.002540    -0.004626
# AIRLINE_AIRPORT_FLIGHTS_MONTH  0.036648      0.001317    -0.000206
# AVG_MONTHLY_PASS_AIRPORT       0.001516      0.000516    -0.000342
# AVG_MONTHLY_PASS_AIRLINE      -0.002357     -0.000213    -0.003620
# CARGO_HANDLING                -0.009120     -0.002825     0.000413
# FLT_ATTENDANTS_PER_PASS        0.003142      0.002131     0.000378
# GROUND_SERV_PER_PASS          -0.006976      0.000230     0.002181
# PLANE_AGE                     -0.018068     -0.000269    -0.003918
# PRCP                          -0.005187      0.016722     0.017159
# SNOW                          -0.053381      0.005042    -0.004371
# SNWD                          -0.088859      0.006311    -0.011323
# TMAX                           0.171282      0.016879     0.007677
# AWND                          -0.119111      0.040346     0.000752
# IS_DELAYED                    -0.016193      0.003041     0.005666
#
#                                DEPARTING_AIRPORT      DEST  DEP_TIME_BLK  \
# MONTH                                  -0.003732 -0.006372      0.000513
# DAY_OF_MONTH                            0.002837 -0.001285     -0.001562
# DAY_OF_WEEK                             0.001732  0.002943      0.008441
# DEPARTING_AIRPORT                       1.000000  0.012353     -0.042449
# DEST                                    0.012353  1.000000      0.017773
# DEP_TIME_BLK                           -0.042449  0.017773      1.000000
# DISTANCE                                0.098492  0.075202     -0.027610
# SEGMENT_NUMBER                         -0.033514 -0.004623      0.737310
# CONCURRENT_FLIGHTS                     -0.364522  0.035293      0.049274
# NUMBER_OF_SEATS                         0.061262  0.015641     -0.023026
# CARRIER_NAME                            0.136779  0.019911      0.011774
# AIRPORT_FLIGHTS_MONTH                  -0.385114  0.038118      0.102454
# AIRLINE_FLIGHTS_MONTH                   0.040653  0.008949     -0.006321
# AIRLINE_AIRPORT_FLIGHTS_MONTH          -0.346656  0.064850      0.113556
# AVG_MONTHLY_PASS_AIRPORT               -0.350215  0.047461      0.102769
# AVG_MONTHLY_PASS_AIRLINE                0.017189 -0.010912     -0.015565
# CARGO_HANDLING                         -0.000698  0.009503     -0.020386
# FLT_ATTENDANTS_PER_PASS                -0.050244  0.004917     -0.001360
# GROUND_SERV_PER_PASS                    0.006561  0.028326     -0.024924
# PLANE_AGE                              -0.040894 -0.037299      0.010948
# PRCP                                   -0.030233 -0.020566     -0.003780
# SNOW                                    0.004551  0.003673     -0.003925
# SNWD                                   -0.038147  0.007340     -0.005710
# TMAX                                    0.013161 -0.017343      0.021328
# AWND                                   -0.061727 -0.006082      0.001732
# IS_DELAYED                             -0.002470  0.009433      0.177448
#
#                                DISTANCE  SEGMENT_NUMBER  CONCURRENT_FLIGHTS  \
# MONTH                         -0.003786        0.020130            0.026436
# DAY_OF_MONTH                   0.001973       -0.000607            0.000660
# DAY_OF_WEEK                    0.014112       -0.026466           -0.027232
# DEPARTING_AIRPORT              0.098492       -0.033514           -0.364522
# DEST                           0.075202       -0.004623            0.035293
# DEP_TIME_BLK                  -0.027610        0.737310            0.049274
# DISTANCE                       1.000000       -0.242376           -0.036127
# SEGMENT_NUMBER                -0.242376        1.000000            0.006736
# CONCURRENT_FLIGHTS            -0.036127        0.006736            1.000000
# NUMBER_OF_SEATS                0.456127       -0.208146           -0.066207
# CARRIER_NAME                  -0.049043        0.069646           -0.147131
# AIRPORT_FLIGHTS_MONTH         -0.010739        0.036319            0.842523
# AIRLINE_FLIGHTS_MONTH         -0.014278        0.030128           -0.068037
# AIRLINE_AIRPORT_FLIGHTS_MONTH -0.030720        0.049905            0.575820
# AVG_MONTHLY_PASS_AIRPORT       0.037860        0.017065            0.802467
# AVG_MONTHLY_PASS_AIRLINE       0.115922       -0.057948           -0.033570
# CARGO_HANDLING                 0.042916       -0.020133           -0.067438
# FLT_ATTENDANTS_PER_PASS        0.169596       -0.102945            0.127184
# GROUND_SERV_PER_PASS           0.285271       -0.189199            0.104170
# PLANE_AGE                     -0.137902        0.079894            0.037866
# PRCP                          -0.013098       -0.016659           -0.012638
# SNOW                           0.000188       -0.014796           -0.014930
# SNWD                          -0.007706       -0.007161           -0.021376
# TMAX                           0.004168        0.031896            0.020139
# AWND                           0.024092       -0.026695            0.054053
# IS_DELAYED                     0.054035        0.129363            0.011263
#
#                                NUMBER_OF_SEATS  ...  CARGO_HANDLING  \
# MONTH                                 0.002932  ...       -0.009120
# DAY_OF_MONTH                          0.000729  ...       -0.002825
# DAY_OF_WEEK                           0.009340  ...        0.000413
# DEPARTING_AIRPORT                     0.061262  ...       -0.000698
# DEST                                  0.015641  ...        0.009503
# DEP_TIME_BLK                         -0.023026  ...       -0.020386
# DISTANCE                              0.456127  ...        0.042916
# SEGMENT_NUMBER                       -0.208146  ...       -0.020133
# CONCURRENT_FLIGHTS                   -0.066207  ...       -0.067438
# NUMBER_OF_SEATS                       1.000000  ...        0.358686
# CARRIER_NAME                         -0.043519  ...       -0.244579
# AIRPORT_FLIGHTS_MONTH                -0.002917  ...       -0.046500
# AIRLINE_FLIGHTS_MONTH                 0.314016  ...        0.661873
# AIRLINE_AIRPORT_FLIGHTS_MONTH         0.169216  ...        0.130486
# AVG_MONTHLY_PASS_AIRPORT              0.055072  ...       -0.059458
# AVG_MONTHLY_PASS_AIRLINE              0.561537  ...        0.690651
# CARGO_HANDLING                        0.358686  ...        1.000000
# FLT_ATTENDANTS_PER_PASS               0.208898  ...       -0.130505
# GROUND_SERV_PER_PASS                  0.344619  ...        0.095656
# PLANE_AGE                            -0.108893  ...        0.029006
# PRCP                                 -0.011384  ...       -0.008046
# SNOW                                 -0.006468  ...       -0.013547
# SNWD                                 -0.014613  ...       -0.019284
# TMAX                                  0.062273  ...        0.053826
# AWND                                 -0.024643  ...       -0.037512
# IS_DELAYED                            0.089820  ...        0.102733
#
#                                FLT_ATTENDANTS_PER_PASS  GROUND_SERV_PER_PASS  \
# MONTH                                         0.003142             -0.006976
# DAY_OF_MONTH                                  0.002131              0.000230
# DAY_OF_WEEK                                   0.000378              0.002181
# DEPARTING_AIRPORT                            -0.050244              0.006561
# DEST                                          0.004917              0.028326
# DEP_TIME_BLK                                 -0.001360             -0.024924
# DISTANCE                                      0.169596              0.285271
# SEGMENT_NUMBER                               -0.102945             -0.189199
# CONCURRENT_FLIGHTS                            0.127184              0.104170
# NUMBER_OF_SEATS                               0.208898              0.344619
# CARRIER_NAME                                 -0.009194             -0.126167
# AIRPORT_FLIGHTS_MONTH                         0.145928              0.107524
# AIRLINE_FLIGHTS_MONTH                        -0.034067             -0.057189
# AIRLINE_AIRPORT_FLIGHTS_MONTH                 0.135247              0.145361
# AVG_MONTHLY_PASS_AIRPORT                      0.155713              0.127566
# AVG_MONTHLY_PASS_AIRLINE                      0.157259              0.216394
# CARGO_HANDLING                               -0.130505              0.095656
# FLT_ATTENDANTS_PER_PASS                       1.000000              0.513821
# GROUND_SERV_PER_PASS                          0.513821              1.000000
# PLANE_AGE                                     0.204833              0.193897
# PRCP                                          0.002497             -0.002917
# SNOW                                          0.009953              0.002105
# SNWD                                         -0.000973             -0.000418
# TMAX                                         -0.009099             -0.006381
# AWND                                          0.061844              0.038399
# IS_DELAYED                                   -0.009866             -0.031001
#
#                                PLANE_AGE      PRCP      SNOW      SNWD  \
# MONTH                          -0.018068 -0.005187 -0.053381 -0.088859
# DAY_OF_MONTH                   -0.000269  0.016722  0.005042  0.006311
# DAY_OF_WEEK                    -0.003918  0.017159 -0.004371 -0.011323
# DEPARTING_AIRPORT              -0.040894 -0.030233  0.004551 -0.038147
# DEST                           -0.037299 -0.020566  0.003673  0.007340
# DEP_TIME_BLK                    0.010948 -0.003780 -0.003925 -0.005710
# DISTANCE                       -0.137902 -0.013098  0.000188 -0.007706
# SEGMENT_NUMBER                  0.079894 -0.016659 -0.014796 -0.007161
# CONCURRENT_FLIGHTS              0.037866 -0.012638 -0.014930 -0.021376
# NUMBER_OF_SEATS                -0.108893 -0.011384 -0.006468 -0.014613
# CARRIER_NAME                    0.047404 -0.014218  0.015770  0.001301
# AIRPORT_FLIGHTS_MONTH           0.024356 -0.008895 -0.003996 -0.025424
# AIRLINE_FLIGHTS_MONTH           0.168337 -0.008497 -0.012925 -0.024216
# AIRLINE_AIRPORT_FLIGHTS_MONTH   0.118697  0.000508 -0.017093 -0.029943
# AVG_MONTHLY_PASS_AIRPORT        0.027703 -0.012665  0.000743 -0.017681
# AVG_MONTHLY_PASS_AIRLINE        0.217499 -0.003959 -0.006656 -0.017760
# CARGO_HANDLING                  0.029006 -0.008046 -0.013547 -0.019284
# FLT_ATTENDANTS_PER_PASS         0.204833  0.002497  0.009953 -0.000973
# GROUND_SERV_PER_PASS            0.193897 -0.002917  0.002105 -0.000418
# PLANE_AGE                       1.000000  0.008782 -0.002608 -0.000254
# PRCP                            0.008782  1.000000  0.071586 -0.006768
# SNOW                           -0.002608  0.071586  1.000000  0.274509
# SNWD                           -0.000254 -0.006768  0.274509  1.000000
# TMAX                            0.005014 -0.023846 -0.208451 -0.281132
# AWND                           -0.000908  0.097066  0.077957  0.022338
# IS_DELAYED                      0.002030  0.065390  0.045764  0.028165
#
#                                    TMAX      AWND  IS_DELAYED
# MONTH                          0.171282 -0.119111   -0.016193
# DAY_OF_MONTH                   0.016879  0.040346    0.003041
# DAY_OF_WEEK                    0.007677  0.000752    0.005666
# DEPARTING_AIRPORT              0.013161 -0.061727   -0.002470
# DEST                          -0.017343 -0.006082    0.009433
# DEP_TIME_BLK                   0.021328  0.001732    0.177448
# DISTANCE                       0.004168  0.024092    0.054035
# SEGMENT_NUMBER                 0.031896 -0.026695    0.129363
# CONCURRENT_FLIGHTS             0.020139  0.054053    0.011263
# NUMBER_OF_SEATS                0.062273 -0.024643    0.089820
# CARRIER_NAME                   0.000279  0.022413    0.033298
# AIRPORT_FLIGHTS_MONTH          0.032807  0.064969    0.029597
# AIRLINE_FLIGHTS_MONTH          0.080850 -0.052464    0.104066
# AIRLINE_AIRPORT_FLIGHTS_MONTH  0.066775  0.007555    0.056614
# AVG_MONTHLY_PASS_AIRPORT       0.010980  0.064014    0.030916
# AVG_MONTHLY_PASS_AIRLINE       0.051818 -0.036895    0.098307
# CARGO_HANDLING                 0.053826 -0.037512    0.102733
# FLT_ATTENDANTS_PER_PASS       -0.009099  0.061844   -0.009866
# GROUND_SERV_PER_PASS          -0.006381  0.038399   -0.031001
# PLANE_AGE                      0.005014 -0.000908    0.002030
# PRCP                          -0.023846  0.097066    0.065390
# SNOW                          -0.208451  0.077957    0.045764
# SNWD                          -0.281132  0.022338    0.028165
# TMAX                           1.000000 -0.173583   -0.011618
# AWND                          -0.173583  1.000000    0.044311
# IS_DELAYED                    -0.011618  0.044311    1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# Now, we convert this dataframe into a numpy array to begin the model training process

# %%
train_data_np = train_data.to_numpy()

# %% [markdown]
# Then, we separate the features from the target variable

# %%
X = train_data_np[:, :-1] # All rows, and every column except for the last one, which is the target variable
y = train_data_np[:, -1]

# %% [markdown]
# Now, we split the data into a training set and testing set so we can both train the model, and evaluate the moedl after training it

# %%
from sklearn.model_selection import train_test_split
# IF YOUR MODEL IS TAKING TOO LONG TO RUN, INCREASE THE TEST SIZE to 0.7, original 0.2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# Now, we define our model. This is truly where the magic happens, and it's truly just plug and play. Feel free to swap out my model with any one of these, and explore how the results change!

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
model = RandomForestClassifier(
    n_estimators=150,
    n_jobs=-1
)

# %%
model = QuadraticDiscriminantAnalysis()

# %%
model = AdaBoostClassifier(
    n_estimators=200
)

# %% [markdown]
# Here, I'm just defining a random model

# %%
# model = GaussianNB()
model = KNeighborsClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=200)

# %% [markdown]
# Great! Now that our model is done training, let's see how we did. To evaluate our model we must define what metric we evaluate our model on. We'll be using AUROC

# %%
from sklearn.metrics import roc_auc_score

# %%
# Use our testing subset and make predictions
y_test_predictions_probabilities = model.predict_proba(X_test)

# %% [markdown]
# `predict_proba` is a function that returns the probability/confidence of the model for each class.

# %%
y_test_predictions_probabilities
# Out:
# array([[0.49959828, 0.50040172],
#        [0.50066796, 0.49933204],
#        [0.50077064, 0.49922936],
#        ...,
#        [0.50099127, 0.49900873],
#        [0.49896267, 0.50103733],
#        [0.50237652, 0.49762348]])

# %% [markdown]
# If we exaime the first row [0.57795736, 0.42204264], we interpret this as the model is 57% confident that the label should be 0, and 42% confident that the label should be 1. The AUROC Score is concerned only with the probability of the 1 label, so we must grab the second column

# %%
y_test_predictions = y_test_predictions_probabilities[:, 1] # All rows, second column

# %%
roc_auc_score(y_test, y_test_predictions)
# Out:
# 0.6823558236652204

# %% [markdown]
# This is decent!

# %% [markdown]
# Now let's load our test data and make predictions on that, then create our submission file

# %%
test_data = pd.read_csv("datathon_test.csv")

# %%
test_data
# Out:
#             Id  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  \
# 0            0      7             1            1
# 1            1      4            12            5
# 2            2     10            11            5
# 3            3      9            26            4
# 4            4      8            13            2
# ...        ...    ...           ...          ...
# 298806  298806      6            16            7
# 298807  298807      3            20            3
# 298808  298808     10             6            7
# 298809  298809      7            17            3
# 298810  298810      3             4            1
#
#                         DEPARTING_AIRPORT ORIGIN_CITY_NAME DEST  \
# 0       Minneapolis-St Paul International  Minneapolis, MN  PHL
# 1               Los Angeles International  Los Angeles, CA  BNA
# 2       Ronald Reagan Washington National   Washington, DC  SYR
# 3                               LaGuardia     New York, NY  ORD
# 4              Detroit Metro Wayne County      Detroit, MI  ERI
# ...                                   ...              ...  ...
# 298806       Chicago O'Hare International      Chicago, IL  AVL
# 298807                Tampa International        Tampa, FL  EWR
# 298808      John F. Kennedy International     New York, NY  MCO
# 298809             General Mitchell Field    Milwaukee, WI  LGA
# 298810   Phoenix Sky Harbor International      Phoenix, AZ  SBA
#
#            DEST_CITY_NAME DEP_TIME_BLK  DISTANCE  ...  CARGO_HANDLING  \
# 0        Philadelphia, PA    2000-2059       980  ...            1462
# 1           Nashville, TN    1000-1059      1797  ...            1462
# 2            Syracuse, NY    0700-0759       298  ...               0
# 3             Chicago, IL    2000-2059       733  ...             518
# 4                Erie, PA    2000-2059       164  ...              10
# ...                   ...          ...       ...  ...             ...
# 298806      Asheville, NC    1800-1859       536  ...              10
# 298807         Newark, NJ    0700-0759       997  ...             518
# 298808        Orlando, FL    2100-2159       944  ...              62
# 298809       New York, NY    0600-0659       738  ...           10955
# 298810  Santa Barbara, CA    2100-2159       455  ...               0
#
#         FLT_ATTENDANTS_PER_PASS  GROUND_SERV_PER_PASS  PLANE_AGE  \
# 0                      0.000144              0.000149         18
# 1                      0.000144              0.000149         18
# 2                      0.000000              0.000090         16
# 3                      0.000254              0.000229         12
# 4                      0.000034              0.000099         16
# ...                         ...                   ...        ...
# 298806                 0.000034              0.000099         17
# 298807                 0.000254              0.000229          4
# 298808                 0.000160              0.000127         13
# 298809                 0.000062              0.000099         19
# 298810                 0.000000              0.000091         14
#
#                                   PREVIOUS_AIRPORT  PRCP  SNOW  SNWD  TMAX  \
# 0                            Bradley International  0.00   0.0   0.0  93.0
# 1       Cincinnati/Northern Kentucky International  0.00   0.0   0.0  73.0
# 2                            Norfolk International  0.00   0.0   0.0  75.0
# 3                     Chicago O'Hare International  0.00   0.0   0.0  82.0
# 4             Kalamazoo/Battle Creek International  0.00   0.0   0.0  88.0
# ...                                            ...   ...   ...   ...   ...
# 298806                        Duluth International  0.07   0.0   0.0  60.0
# 298807                                        NONE  0.00   0.0   0.0  76.0
# 298808                       Orlando International  0.01   0.0   0.0  71.0
# 298809                                        NONE  0.00   0.0   0.0  84.0
# 298810             San Luis Obispo County Regional  0.00   0.0   0.0  74.0
#
#          AWND
# 0        4.70
# 1       12.30
# 2        5.82
# 3        9.40
# 4        7.61
# ...       ...
# 298806   9.62
# 298807   8.50
# 298808  10.96
# 298809   6.71
# 298810   4.92
#
# [298811 rows x 30 columns]

# %% [markdown]
# Since we used only the "SEGMENT_NUMBER", "NUMBER_OF_SEATS", "PRCP", "CARGO_HANDLING", "AIRLINE_FLIGHTS_MONTH", "DEP_TIME_BLK" columns when training, we must only use these when testing, because these features are what our model is trained on

# %% [markdown]
# Note, we MUST keep the Id column here to create our submission file

# %%
test_data = test_data[['Id','DEST',
       'DEP_TIME_BLK', 'DISTANCE', 'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS',
       'NUMBER_OF_SEATS', 'CARRIER_NAME', 'AIRPORT_FLIGHTS_MONTH',
       'AIRLINE_FLIGHTS_MONTH', 'AIRLINE_AIRPORT_FLIGHTS_MONTH',
       'AVG_MONTHLY_PASS_AIRPORT', 'AVG_MONTHLY_PASS_AIRLINE',
       'CARGO_HANDLING','PLANE_AGE', 'PRCP', 'SNOW', 'SNWD', 'AWND']]

# %%
test_data.head()
# Out:
#    Id DEST DEP_TIME_BLK  DISTANCE  SEGMENT_NUMBER  CONCURRENT_FLIGHTS  \
# 0   0  PHL    2000-2059       980               4                  47
# 1   1  BNA    1000-1059      1797               2                  40
# 2   2  SYR    0700-0759       298               2                  23
# 3   3  ORD    2000-2059       733               5                  28
# 4   4  ERI    2000-2059       164               9                  64
#
#    NUMBER_OF_SEATS           CARRIER_NAME  AIRPORT_FLIGHTS_MONTH  \
# 0              132   Delta Air Lines Inc.                  14787
# 1              160   Delta Air Lines Inc.                  17338
# 2               50            Comair Inc.                  11637
# 3              120  United Air Lines Inc.                  13731
# 4               50  SkyWest Airlines Inc.                  14439
#
#    AIRLINE_FLIGHTS_MONTH  AIRLINE_AIRPORT_FLIGHTS_MONTH  \
# 0                  86274                           6606
# 1                  76299                           2995
# 2                  23411                           2415
# 3                  51182                            740
# 4                  70841                           4166
#
#    AVG_MONTHLY_PASS_AIRPORT  AVG_MONTHLY_PASS_AIRLINE  CARGO_HANDLING  \
# 0                   1581456                  12460183            1462
# 1                   2780593                  12460183            1462
# 2                    955406                   1245396               0
# 3                   1208249                   8501631             518
# 4                   1486066                   3472966              10
#
#    PLANE_AGE  PRCP  SNOW  SNWD   AWND
# 0         18   0.0   0.0   0.0   4.70
# 1         18   0.0   0.0   0.0  12.30
# 2         16   0.0   0.0   0.0   5.82
# 3         12   0.0   0.0   0.0   9.40
# 4         16   0.0   0.0   0.0   7.61

# %% [markdown]
# Me must make the DEPARTING_AIRPORT, CARRIER_NAME, and  DEP_TIME_BLK. numerical using the SAME label encoder we used on our train data for consistency, but first, as mentioned before, we must check if there are any values in these categories that weren't in the training data so we don't run into any errors. If we find any, we replace them with "UNSEEN"

# %%
new_dep_time_blk = []
for value in test_data["DEP_TIME_BLK"]:
       # If the value is unknown, we tag the "UNSEEN"
       if value not in dep_time_blk_le.classes_:
              new_dep_time_blk.append("UNSEEN")
       # If the value is known to the labelencoder, we can safely append that value
       else:
              new_dep_time_blk.append(value)
# Replace
test_data["DEP_TIME_BLK"] = new_dep_time_blk
# Out:
# /var/folders/p6/0vclxwpx5bn0v72kzlpwhszr0000gn/T/ipykernel_9274/2359365467.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["DEP_TIME_BLK"] = new_dep_time_blk

# %%
new_departing_airport = []
for value in test_data["DEPARTING_AIRPORT"]:
       # If the value is unknown, we tag the "UNSEEN"
       if value not in departing_airport_le.classes_:
              new_departing_airport.append("UNSEEN")
       # If the value is known to the labelencoder, we can safely append that value
       else:
              new_departing_airport.append(value)
# Replace
test_data["DEPARTING_AIRPORT"] = new_departing_airport
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DEPARTING_AIRPORT'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/markwang/Desktop/5C Datathon/5c_datathon_starter_code.ipynb Cell 54 line 2
#       <a href='vscode-notebook-cell:/Users/markwang/Desktop/5C%20Datathon/5c_datathon_starter_code.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> new_departing_airport = []
# ----> <a href='vscode-notebook-cell:/Users/markwang/Desktop/5C%20Datathon/5c_datathon_starter_code.ipynb#Y102sZmlsZQ%3D%3D?line=1'>2</a> for value in test_data["DEPARTING_AIRPORT"]:
#       <a href='vscode-notebook-cell:/Users/markwang/Desktop/5C%20Datathon/5c_datathon_starter_code.ipynb#Y102sZmlsZQ%3D%3D?line=2'>3</a>        # If the value is unknown, we tag the "UNSEEN"
#       <a href='vscode-notebook-cell:/Users/markwang/Desktop/5C%20Datathon/5c_datathon_starter_code.ipynb#Y102sZmlsZQ%3D%3D?line=3'>4</a>        if value not in departing_airport_le.classes_:
#       <a href='vscode-notebook-cell:/Users/markwang/Desktop/5C%20Datathon/5c_datathon_starter_code.ipynb#Y102sZmlsZQ%3D%3D?line=4'>5</a>               new_departing_airport.append("UNSEEN")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'DEPARTING_AIRPORT'

# %%
new_carrier = []
for value in test_data["CARRIER_NAME"]:
       # If the value is unknown, we tag the "UNSEEN"
       if value not in carrier_name_le.classes_:
              new_carrier.append("UNSEEN")
       # If the value is known to the labelencoder, we can safely append that value
       else:
              new_carrier.append(value)
# Replace
test_data["CARRIER_NAME"] = new_carrier
# Out:
# /var/folders/p6/0vclxwpx5bn0v72kzlpwhszr0000gn/T/ipykernel_9274/361337649.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["CARRIER_NAME"] = new_carrier

# %%
new_dest = []
for value in test_data["DEST"]:
       # If the value is unknown, we tag the "UNSEEN"
       if value not in dest_le.classes_:
              new_dest.append("UNSEEN")
       # If the value is known to the labelencoder, we can safely append that value
       else:
              new_dest.append(value)
# Replace
test_data["DEST"] = new_dest
# Out:
# /var/folders/p6/0vclxwpx5bn0v72kzlpwhszr0000gn/T/ipykernel_9274/3354664469.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["DEST"] = new_dest

# %%
test_data
# Out:
#             Id   AWND  AIRLINE_FLIGHTS_MONTH  DISTANCE  \
# 0            0   4.70                  86274       980
# 1            1  12.30                  76299      1797
# 2            2   5.82                  23411       298
# 3            3   9.40                  51182       733
# 4            4   7.61                  70841       164
# ...        ...    ...                    ...       ...
# 298806  298806   9.62                  68083       536
# 298807  298807   8.50                  52866       997
# 298808  298808  10.96                  24795       944
# 298809  298809   6.71                 116615       738
# 298810  298810   4.92                  18296       455
#
#         AVG_MONTHLY_PASS_AIRLINE  SNOW  PRCP  SEGMENT_NUMBER  CARGO_HANDLING
# 0                       12460183   0.0  0.00               4            1462
# 1                       12460183   0.0  0.00               2            1462
# 2                        1245396   0.0  0.00               2               0
# 3                        8501631   0.0  0.00               5             518
# 4                        3472966   0.0  0.00               9              10
# ...                          ...   ...   ...             ...             ...
# 298806                   3472966   0.0  0.07               6              10
# 298807                   8501631   0.0  0.00               1             518
# 298808                   3190369   0.0  0.01               5              62
# 298809                  13382999   0.0  0.00               1           10955
# 298810                   1191889   0.0  0.00               6               0
#
# [298811 rows x 9 columns]

# %%
test_data["DEP_TIME_BLK"] = dep_time_blk_le.transform(test_data["DEP_TIME_BLK"])
test_data["CARRIER_NAME"] = carrier_name_le.transform(test_data["CARRIER_NAME"])
test_data["DEST"] = dest_le.transform(test_data["DEST"])
# Out:
# /var/folders/p6/0vclxwpx5bn0v72kzlpwhszr0000gn/T/ipykernel_9274/3222516485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["DEP_TIME_BLK"] = dep_time_blk_le.transform(test_data["DEP_TIME_BLK"])
# /var/folders/p6/0vclxwpx5bn0v72kzlpwhszr0000gn/T/ipykernel_9274/3222516485.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["CARRIER_NAME"] = carrier_name_le.transform(test_data["CARRIER_NAME"])
# /var/folders/p6/0vclxwpx5bn0v72kzlpwhszr0000gn/T/ipykernel_9274/3222516485.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["DEST"] = dest_le.transform(test_data["DEST"])

# %%
test_data
# Out:
#             Id  DEPARTING_AIRPORT  NUMBER_OF_SEATS  PRCP  CARRIER_NAME  \
# 0            0                 48              132  0.00             5
# 1            1                 41              160  0.00             5
# 2            2                 71               50  0.00             4
# 3            3                 36              120  0.00            16
# 4            4                 16               50  0.00            12
# ...        ...                ...              ...   ...           ...
# 298806  298806                 10               50  0.07            12
# 298807  298807                 84              173  0.00            16
# 298808  298808                 31              162  0.01             9
# 298809  298809                 22              143  0.00            13
# 298810  298810                 60               79  0.00            10
#
#         AIRLINE_FLIGHTS_MONTH  DEP_TIME_BLK
# 0                       86274            15
# 1                       76299             5
# 2                       23411             2
# 3                       51182            15
# 4                       70841            15
# ...                       ...           ...
# 298806                  68083            13
# 298807                  52866             2
# 298808                  24795            16
# 298809                 116615             1
# 298810                  18296            16
#
# [298811 rows x 7 columns]

# %% [markdown]
# Great! Let's now do the same thing as we did before

# %%
test_data_np = test_data.to_numpy()

# %% [markdown]
# This is now entirely test data, and we don't need to split using `train_test_split` because we're not training a new model.

# %%
X_TEST = test_data_np[:, 1:] # The first column is the Id column, which we do not want to keep in our predictions

# %%
predictions = model.predict_proba(X_TEST)[:, 1] # Just like before
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/markwang/Desktop/5C Datathon/5c_datathon_starter_code.ipynb Cell 64 line 1
# ----> <a href='vscode-notebook-cell:/Users/markwang/Desktop/5C%20Datathon/5c_datathon_starter_code.ipynb#Y114sZmlsZQ%3D%3D?line=0'>1</a> predictions = model.predict_proba(X_TEST)[:, 1] # Just like before
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:896, in AdaBoostClassifier.predict_proba(self, X)
#     893 if n_classes == 1:
#     894     return np.ones((_num_samples(X), 1))
# --> 896 decision = self.decision_function(X)
#     897 return self._compute_proba_from_decision(decision, n_classes)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:771, in AdaBoostClassifier.decision_function(self, X)
#     752 """Compute the decision function of ``X``.
#     753
#     754 Parameters
#    (...)
#     768     class in ``classes_``, respectively.
#     769 """
#     770 check_is_fitted(self)
# --> 771 X = self._check_X(X)
#     773 n_classes = self.n_classes_
#     774 classes = self.classes_[:, np.newaxis]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:101, in BaseWeightBoosting._check_X(self, X)
#      99 def _check_X(self, X):
#     100     # Only called to validate X in non-fit methods, therefore reset=False
# --> 101     return self._validate_data(
#     102         X,
#     103         accept_sparse=["csr", "csc"],
#     104         ensure_2d=True,
#     105         allow_nd=True,
#     106         dtype=None,
#     107         reset=False,
#     108     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:626, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
# --> 626     self._check_n_features(X, reset=reset)
#     628 return out
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:415, in BaseEstimator._check_n_features(self, X, reset)
#     412     return
#     414 if n_features != self.n_features_in_:
# --> 415     raise ValueError(
#     416         f"X has {n_features} features, but {self.__class__.__name__} "
#     417         f"is expecting {self.n_features_in_} features as input."
#     418     )
#
# ValueError: X has 18 features, but AdaBoostClassifier is expecting 25 features as input.

# %%
predictions
# Out:
# array([0.50050824, 0.50079592, 0.49995737, ..., 0.50015867, 0.50099369,
#        0.50016569])

# %%
len(predictions)
# Out:
# 298811

# %% [markdown]
# Now, time to make our submission file! The submission file has two columns to named exactly this way. "Id", and "IS_DELAYED"

# %%
submission = test_data[["Id"]]

# %%
submission
# Out:
#             Id
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ...        ...
# 298806  298806
# 298807  298807
# 298808  298808
# 298809  298809
# 298810  298810
#
# [298811 rows x 1 columns]

# %%
submission["IS_DELAYED"] = predictions
# Out:
# /var/folders/p6/0vclxwpx5bn0v72kzlpwhszr0000gn/T/ipykernel_9274/3329059061.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission["IS_DELAYED"] = predictions

# %%
submission
# Out:
#             Id  IS_DELAYED
# 0            0    0.500508
# 1            1    0.500796
# 2            2    0.499957
# 3            3    0.499865
# 4            4    0.500024
# ...        ...         ...
# 298806  298806    0.501114
# 298807  298807    0.499989
# 298808  298808    0.500159
# 298809  298809    0.500994
# 298810  298810    0.500166
#
# [298811 rows x 2 columns]

# %% [markdown]
# Now, we save the dataframe into a CSV

# %%
submission.to_csv("test2_submission.csv", index=False)
